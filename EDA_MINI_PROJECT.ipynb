# %%
#Data Preprocessing:
# 1.Import the necessary libraries and read the data.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
datafile=pd.read_csv('C:/Users/welcome/Excel Documents/fifa.csv')

# %%
datafile.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
# 2.Drop any columns that you deem unecessary for analysis.

# %%
datafile_drop=datafile.drop(columns=['Photo','Flag','Club Logo','Jersey Number'])

# %%
datafile_drop.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage Preferred Foot  ...  Composure  \
# 0         FC Barcelona  €110.5M  €565K           Left  ...       96.0
# 1             Juventus     €77M  €405K          Right  ...       95.0
# 2  Paris Saint-Germain  €118.5M  €290K          Right  ...       94.0
# 3    Manchester United     €72M  €260K          Right  ...       68.0
# 4      Manchester City    €102M  €355K          Right  ...       88.0
#
#    Marking  StandingTackle SlidingTackle GKDiving GKHandling GKKicking  \
# 0     33.0            28.0          26.0      6.0       11.0      15.0
# ...

# %%
numerical_data=datafile_drop.select_dtypes(include=np.number)

# %%
numerical_data.head()
# Out:
#        ID  Age  Overall  Potential  International Reputation  Weak Foot  \
# 0  158023   31       94         94                       5.0        4.0
# 1   20801   33       94         94                       5.0        4.0
# 2  190871   26       92         93                       5.0        5.0
# 3  193080   27       91         93                       4.0        3.0
# 4  192985   27       91         92                       4.0        5.0
#
#    Skill Moves  Crossing  Finishing  HeadingAccuracy  ...  Penalties  \
# 0          4.0      84.0       95.0             70.0  ...       75.0
# 1          5.0      84.0       94.0             89.0  ...       85.0
# 2          5.0      79.0       87.0             62.0  ...       81.0
# 3          1.0      17.0       13.0             21.0  ...       40.0
# 4          4.0      93.0       82.0             55.0  ...       79.0
#
#    Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# ...

# %%
categorical_data=datafile_drop.select_dtypes(exclude=np.number)

# %%
categorical_data.head()
# Out:
#                 Name Nationality                 Club    Value   Wage  \
# 0           L. Messi   Argentina         FC Barcelona  €110.5M  €565K
# 1  Cristiano Ronaldo    Portugal             Juventus     €77M  €405K
# 2          Neymar Jr      Brazil  Paris Saint-Germain  €118.5M  €290K
# 3             De Gea       Spain    Manchester United     €72M  €260K
# 4       K. De Bruyne     Belgium      Manchester City    €102M  €355K
#
#   Preferred Foot       Work Rate   Body Type Position        Joined  \
# 0           Left  Medium/ Medium       Messi       RF   Jul 1, 2004
# 1          Right       High/ Low  C. Ronaldo       ST  Jul 10, 2018
# 2          Right    High/ Medium      Neymar       LW   Aug 3, 2017
# 3          Right  Medium/ Medium        Lean       GK   Jul 1, 2011
# 4          Right      High/ High      Normal      RCM  Aug 30, 2015
#
#   Loaned From Contract Valid Until Height  Weight Release Clause
# 0         NaN                 2021    5'7  159lbs        €226.5M
# ...

# %%
# 3.The following columns need to be converted for further analysis:

#'Value'
# Amount with Euro symbol as prefix and suffix ‘K’ or ‘M’ indicating thousands and millions respectively.
# Convert to Float after getting rid of currency symbol and suffix.

# 'Wage'
# Amount with Euro symbol as prefix and suffix ‘K’ or ‘M’ indicating thousands and millions respectively.
# Convert to Float after getting rid of currency symbol and suffix.

#'Joined'	Year as a string, in some cases complete date as string	Convert to int with only year

#'Contract Valid Until'	Date as a string 	Convert to datetime type

#'Height'	In inches with a quotation mark 	Convert to Float with decimal points

#'Weight'	Contains the suffix lbs 	Remove the suffix and convert to float

#'Release Clause'
# Amount with Euro symbol as prefix and suffix ‘K’ or ‘M’ indicating thousands and millions respectively.
# Convert to Float after getting rid of currency symbol and suffix.

# %%
def clean_release(x):
    x=str(x)
    if '€' in x:
        x=x.replace('€','')
    if 'K' in x:
        K=10**3
        x=x.replace('K','')
        x=str(float(x)*K)
    if 'M' in x:
        M=10**6
        x=x.replace('M','')
        x=str(float(x)*M)
    return x

# %%
datafile_drop['Value'] = datafile_drop['Value'].apply(clean_release).astype('float')

# %%
datafile_drop['Value'].head()
# Out:
# 0    110500000.0
# 1     77000000.0
# 2    118500000.0
# 3     72000000.0
# 4    102000000.0
# Name: Value, dtype: float64

# %%
datafile_drop['Wage'] = datafile_drop['Wage'].apply(clean_release).astype('float')

# %%
datafile_drop['Wage'].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %%
datafile_drop['Release Clause']=datafile_drop['Release Clause'].apply(clean_release).astype('float')

# %%
datafile_drop['Release Clause'].head()
# Out:
# 0    226500000.0
# 1    127100000.0
# 2    228100000.0
# 3    138600000.0
# 4    196400000.0
# Name: Release Clause, dtype: float64

# %%
categorical_data=categorical_data.drop(['Value','Wage','Release Clause'],axis=1)

# %%
categorical_data.head()
# Out:
#                 Name Nationality                 Club Preferred Foot  \
# 0           L. Messi   Argentina         FC Barcelona           Left
# 1  Cristiano Ronaldo    Portugal             Juventus          Right
# 2          Neymar Jr      Brazil  Paris Saint-Germain          Right
# 3             De Gea       Spain    Manchester United          Right
# 4       K. De Bruyne     Belgium      Manchester City          Right
#
#         Work Rate   Body Type Position        Joined Loaned From  \
# 0  Medium/ Medium       Messi       RF   Jul 1, 2004         NaN
# 1       High/ Low  C. Ronaldo       ST  Jul 10, 2018         NaN
# 2    High/ Medium      Neymar       LW   Aug 3, 2017         NaN
# 3  Medium/ Medium        Lean       GK   Jul 1, 2011         NaN
# 4      High/ High      Normal      RCM  Aug 30, 2015         NaN
#
#   Contract Valid Until Height  Weight
# 0                 2021    5'7  159lbs
# 1                 2022    6'2  183lbs
# 2                 2022    5'9  150lbs
# ...

# %%
datafile_drop['Contract Valid Until']=categorical_data['Contract Valid Until'].astype('datetime64[ns]')

# %%
categorical_data=categorical_data.drop('Contract Valid Until',axis=1)

# %%
categorical_data.head()
# Out:
#                 Name Nationality                 Club Preferred Foot  \
# 0           L. Messi   Argentina         FC Barcelona           Left
# 1  Cristiano Ronaldo    Portugal             Juventus          Right
# 2          Neymar Jr      Brazil  Paris Saint-Germain          Right
# 3             De Gea       Spain    Manchester United          Right
# 4       K. De Bruyne     Belgium      Manchester City          Right
#
#         Work Rate   Body Type Position        Joined Loaned From Height  \
# 0  Medium/ Medium       Messi       RF   Jul 1, 2004         NaN    5'7
# 1       High/ Low  C. Ronaldo       ST  Jul 10, 2018         NaN    6'2
# 2    High/ Medium      Neymar       LW   Aug 3, 2017         NaN    5'9
# 3  Medium/ Medium        Lean       GK   Jul 1, 2011         NaN    6'4
# 4      High/ High      Normal      RCM  Aug 30, 2015         NaN   5'11
#
#    Weight
# 0  159lbs
# 1  183lbs
# 2  150lbs
# 3  168lbs
# 4  154lbs

# %%
datafile_drop['Joined']=datafile_drop['Joined'].apply(lambda x: str(x)[7:12]).dropna()

# %%
datafile_drop['Joined'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-ab33843a46f9> in <module>
# ----> 1 datafile_drop['Joined'].astype(int)
#
# ~\anaconda3\envs\notebook\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5872         else:
#    5873             # else, only a single dtype is given
# -> 5874             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5875             return self._constructor(new_data).__finalize__(self, method="astype")
#    5876
#
# ~\anaconda3\envs\notebook\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
datafile_drop['Joined'].value_counts()
# Out:
#     18207
# Name: Joined, dtype: int64

# %%
datafile_drop['Joined'].head()
# Out:
# 0     2004
# 1     2018
# 2     2017
# 3     2011
# 4     2015
# Name: Joined, dtype: object

# %%
datafile_drop['Weight']=datafile_drop['Weight'].apply(lambda x: str(x)[0:3]).astype('float')

# %%
datafile_drop['Weight'].head()
# Out:
# 0    159.0
# 1    183.0
# 2    150.0
# 3    168.0
# 4    154.0
# Name: Weight, dtype: float64

# %%
categorical_data=categorical_data.drop('Weight',axis=1)

# %%
categorical_data.head()
# Out:
#                 Name Nationality                 Club Preferred Foot  \
# 0           L. Messi   Argentina         FC Barcelona           Left
# 1  Cristiano Ronaldo    Portugal             Juventus          Right
# 2          Neymar Jr      Brazil  Paris Saint-Germain          Right
# 3             De Gea       Spain    Manchester United          Right
# 4       K. De Bruyne     Belgium      Manchester City          Right
#
#         Work Rate   Body Type Position        Joined Loaned From Height
# 0  Medium/ Medium       Messi       RF   Jul 1, 2004         NaN    5'7
# 1       High/ Low  C. Ronaldo       ST  Jul 10, 2018         NaN    6'2
# 2    High/ Medium      Neymar       LW   Aug 3, 2017         NaN    5'9
# 3  Medium/ Medium        Lean       GK   Jul 1, 2011         NaN    6'4
# 4      High/ High      Normal      RCM  Aug 30, 2015         NaN   5'11

# %%
# 4.Check for missing values and do a mean imputation where necessary.

# %%
datafile_drop.dropna(subset=['Joined'],inplace=True)

# %%
datafile_drop
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club        Value      Wage Preferred Foot  ...  \
# ...

# %%
datafile_drop.dropna(subset=['International Reputation']).isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Nationality                     0
# Overall                         0
# Potential                       0
# Club                          241
# Value                           0
# Wage                            0
# Preferred Foot                  0
# International Reputation        0
# Weak Foot                       0
# Skill Moves                     0
# Work Rate                       0
# Body Type                       0
# Position                       12
# Joined                          0
# Loaned From                 16895
# Contract Valid Until          241
# Height                          0
# Weight                          0
# Crossing                        0
# Finishing                       0
# HeadingAccuracy                 0
# ShortPassing                    0
# Volleys                         0
# Dribbling                       0
# ...

# %%
datafile_drop['International Reputation'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
datafile_drop['International Reputation'].mean()
# Out:
# 1.1132220937276283

# %%
datafile_drop['International Reputation'].fillna(datafile_drop['International Reputation'].mean()).isnull().sum()
# Out:
# 0

# %%
datafile_drop['International Reputation']=datafile_drop['International Reputation'].fillna(datafile_drop['International Reputation'].mean())

# %%
datafile_drop['International Reputation'].describe()
# Out:
# count    18207.000000
# mean         1.113222
# std          0.393511
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          5.000000
# Name: International Reputation, dtype: float64

# %%
datafile_drop
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club        Value      Wage Preferred Foot  ...  \
# ...

# %%
numerical_data=datafile_drop.select_dtypes(include=np.number)

# %%
numerical_data.head()
# Out:
#        ID  Age  Overall  Potential        Value      Wage  \
# 0  158023   31       94         94  110500000.0  565000.0
# 1   20801   33       94         94   77000000.0  405000.0
# 2  190871   26       92         93  118500000.0  290000.0
# 3  193080   27       91         93   72000000.0  260000.0
# 4  192985   27       91         92  102000000.0  355000.0
#
#    International Reputation  Weak Foot  Skill Moves  Weight  ...  Composure  \
# 0                       5.0        4.0          4.0   159.0  ...       96.0
# 1                       5.0        4.0          5.0   183.0  ...       95.0
# 2                       5.0        5.0          5.0   150.0  ...       94.0
# 3                       4.0        3.0          1.0   168.0  ...       68.0
# 4                       4.0        5.0          4.0   154.0  ...       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# ...

# %%
categorical_data
# Out:
#                      Name Nationality                 Club Preferred Foot  \
# 0                L. Messi   Argentina         FC Barcelona           Left
# 1       Cristiano Ronaldo    Portugal             Juventus          Right
# 2               Neymar Jr      Brazil  Paris Saint-Germain          Right
# 3                  De Gea       Spain    Manchester United          Right
# 4            K. De Bruyne     Belgium      Manchester City          Right
# ...                   ...         ...                  ...            ...
# 18202        J. Lundstram     England      Crewe Alexandra          Right
# 18203  N. Christoffersson      Sweden       Trelleborgs FF          Right
# 18204           B. Worman     England     Cambridge United          Right
# 18205      D. Walker-Rice     England      Tranmere Rovers          Right
# 18206           G. Nugent     England      Tranmere Rovers          Right
#
#             Work Rate   Body Type Position        Joined Loaned From Height
# ...

# %%
# Exploratory Data Analysis
# 1.Plot the distribution of Overall rating for all players.

# %%
sns.kdeplot(data=datafile_drop,x='Overall')
plt.axvline(datafile_drop['Overall'].mean(),color='red',linestyle='--')

# %%
# 2.Generate pair plots for the following variables:Overall, Value, Wage, International Reputation, Height, Weight, Release Clause

# %%
df=['Overall','Value','Wage','International Reputation','Height','Weight','Release Clause']

# %%
sns.pairplot(datafile_drop.loc[:,df])

# %%
# 3. Generate a table containing the top 20 players ranked by Overall score and whose contract expires in 2020.
# a) What would the average wage for this set of players be?
# b) What is the average age?
# c) Is there a correlation between the Overall rating and Value for these players?

# %%
# Generate a table containing the top 20 players ranked by Overall Score and Whose contract expires in 2020

# %%
data_20=datafile_drop[datafile_drop['Contract Valid Until']=='2020']

# %%
data_20=data_20.sort_values(by='Overall',ascending=False).head(20)

# %%
data_20
# Out:
#          ID             Name  Age Nationality  Overall  Potential  \
# 3    193080           De Gea   27       Spain       91         93
# 6    177003        L. Modrić   32     Croatia       91         91
# 8    155862     Sergio Ramos   32       Spain       91         91
# 5    183277        E. Hazard   27     Belgium       91         91
# 13   168542      David Silva   32       Spain       90         90
# 21   179813        E. Cavani   31     Uruguay       89         89
# 24   138956     G. Chiellini   33       Italy       89         89
# 31   190460       C. Eriksen   26     Denmark       88         91
# 39   164240     Thiago Silva   33      Brazil       88         88
# 50   175943       D. Mertens   31     Belgium       87         87
# 52   171877        M. Hamšík   30    Slovakia       87         87
# 49   189332       Jordi Alba   29       Spain       87         87
# 46   193041         K. Navas   31  Costa Rica       87         87
# ...

# %%
# what would the average wage for this set of players be?

# %%
data_20['Wage'].mean()
# Out:
# 205450.0

# %%
# what is the average age?

# %%
datafile_drop['Age'].mean()
# Out:
# 25.122205745043114

# %%
data_20['Age'].mean()
# Out:
# 30.65

# %%
# Is there a correlation between the Overall rating and Value for these players?

# %%
data_20[['Overall','Value']].corr()
# Out:
#           Overall     Value
# Overall  1.000000  0.786717
# Value    0.786717  1.000000

# %%
# 4. Generate tables containing the top 5 players by Overall rating for each unique position.
# a) Are there any players appearing in more than one Table. Please point out such players.
# b) What is the average wage one can expect to pay for the top 5 in every position?

# %%
# Generate tables containing the top 5 players by Overall rating for each unique position.

# %%
data_5=datafile_drop.groupby('Position')['Overall'].max().reset_index()

# %%
data_5.head()
# Out:
#   Position  Overall
# 0      CAM       89
# 1       CB       90
# 2      CDM       89
# 3       CF       82
# 4       CM       86

# %%
#  Are there any players appearing in more than one Table. Please point out such players.

# %%
datafile_drop['Name'].value_counts()[datafile_drop['Name'].value_counts()>1]
# Out:
# J. Rodríguez    11
# Paulinho         8
# R. Williams      7
# J. Williams      7
# J. Gómez         6
#                 ..
# Y. Boli          2
# A. Angulo        2
# G. Hauche        2
# A. Al Ghamdi     2
# A. MacDonald     2
# Name: Name, Length: 762, dtype: int64

# %%
# What is the average wage one can expect to pay for the top 5 in every position?

# %%
data_5=datafile_drop.groupby('Position')['Wage'].mean()

# %%
data_5.head(5).reset_index()
# Out:
#   Position          Wage
# 0      CAM  10229.645094
# 1       CB   7704.724409
# 2      CDM   9315.400844
# 3       CF  10216.216216
# 4       CM   8340.746055

# %%
def cleaning_value(x):
    if '€' in str(x) and 'M' in str(x):
        c = str(x).replace('€' , '')
        c = str(c).replace('M' , '')
        c = float(c) * 1000000
        
    else:
        c = str(x).replace('€' , '')
        c = str(c).replace('K' , '')
        c = float(c) * 1000

pos = ['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
       'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
       'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB']
df = pd.DataFrame(columns=pos,index=range(0,5))
df
for col in pos: 
    x=datafile_drop[datafile_drop['Position']==col].sort_values(by='Overall',ascending=False)['Name'].head()
    df[col]=list(x.values)

# %%
df
# Out:
#             RF                 ST          LW             GK           RCM  \
# 0     L. Messi  Cristiano Ronaldo   Neymar Jr         De Gea  K. De Bruyne
# 1   D. Mertens     R. Lewandowski        Isco       J. Oblak     L. Modrić
# 2    D. Valeri            H. Kane    Coutinho  M. ter Stegen    I. Rakitić
# 3  L. Podolski          S. Agüero  L. Insigne    T. Courtois    J. Kimmich
# 4     C. Ciano            G. Bale     L. Sané       M. Neuer          Saúl
#
#                LF              RS           RCB              LCM           CB  \
# 0       E. Hazard       L. Suárez  Sergio Ramos         T. Kroos     D. Godín
# 1       P. Dybala  Z. Ibrahimović  Thiago Silva      David Silva    S. Umtiti
# 2         Iniesta          Falcao         Piqué        M. Hamšík   M. Benatia
# 3  Jonathan Viera   W. Ben Yedder     R. Varane      M. Verratti  N. Otamendi
# 4       S. Blanco         S. Zaza    L. Bonucci  Bruno Fernandes        Naldo
#
# ...

# %%
x
# Out:
# 474    N. Schulz
# 605    J. Hector
# 581      Granell
# 601        Jonny
# 787    J. Mojica
# Name: Name, dtype: object

# %%
from collections import Counter
for i,v in df.iterrows():
    d= Counter(v.values)
    print(d)
    for i in (d.values())>1:
        print(d)
# Out:
# Counter({'L. Messi': 1, 'Cristiano Ronaldo': 1, 'Neymar Jr': 1, 'De Gea': 1, 'K. De Bruyne': 1, 'E. Hazard': 1, 'L. Suárez': 1, 'Sergio Ramos': 1, 'T. Kroos': 1, 'D. Godín': 1, 'N. Kanté': 1, 'A. Griezmann': 1, 'Sergio Busquets': 1, 'E. Cavani': 1, 'G. Chiellini': 1, 'K. Mbappé': 1, 'J. Rodríguez': 1, 'P. Aubameyang': 1, 'Marcelo': 1, 'P. Pogba': 1, 'Bernardo Silva': 1, 'Thiago': 1, 'Azpilicueta': 1, 'J. Cuadrado': 1, 'Luis Alberto': 1, 'M. Ginter': 1, 'N. Schulz': 1})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-3f2bd4aaf5b2> in <module>
#       3     d= Counter(v.values)
#       4     print(d)
# ----> 5     for i in (d.values())>1:
#       6         print(d)
#
# TypeError: '>' not supported between instances of 'dict_values' and 'int'
